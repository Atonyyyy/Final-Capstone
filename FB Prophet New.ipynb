# %%
# Import
from fbprophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import sklearn
import scipy.stats as stats
import seaborn as sns
import datetime 
import statsmodels

# %%
import pandas as pd
df = pd.read_csv('googl.txt')
df=df.dropna()

# %%
df.head()
# Out:
#          Date    Open   High     Low   Close    Volume  OpenInt
# 0  2004-08-19  50.000  52.03  47.980  50.170  44703800        0
# 1  2004-08-20  50.505  54.54  50.250  54.155  22857200        0
# 2  2004-08-23  55.375  56.74  54.525  54.700  18274400        0
# 3  2004-08-24  55.620  55.80  51.785  52.435  15262600        0
# 4  2004-08-25  52.480  54.00  51.940  53.000   9197800        0

# %%
# Prophet requires specific input format.  
# Columns names must be lowercase, date as 'ds', data as 'y'
#goog_prophet = df.Open.dropna().reset_index()
goog_prophet = df.rename(columns={'Date': 'ds', 'Open': 'y'})
goog_prophet.head()
# Out:
#            ds       y   High     Low   Close    Volume  OpenInt
# 0  2004-08-19  50.000  52.03  47.980  50.170  44703800        0
# 1  2004-08-20  50.505  54.54  50.250  54.155  22857200        0
# 2  2004-08-23  55.375  56.74  54.525  54.700  18274400        0
# 3  2004-08-24  55.620  55.80  51.785  52.435  15262600        0
# 4  2004-08-25  52.480  54.00  51.940  53.000   9197800        0

# %%
goog_prophet=goog_prophet[['ds','y']]

# %%
# Model with default parameters
goog_model = Prophet(daily_seasonality=False)
goog_model.fit(goog_prophet)
goog_future = goog_model.make_future_dataframe(periods=365)
goog_forecast = goog_model.predict(goog_future)
# Out:
# C:\Users\ayush\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
goog_forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2004-08-19    50.747891    11.791292    82.045707    50.747891
# 1    2004-08-20    51.026340    11.955789    80.027807    51.026340
# 2    2004-08-23    51.861687    11.754430    79.708757    51.861687
# 3    2004-08-24    52.140136    10.739079    78.233248    52.140136
# 4    2004-08-25    52.418585     8.833096    78.967225    52.418585
# 5    2004-08-26    52.697034    10.993016    79.121559    52.697034
# 6    2004-08-27    52.975483    12.050483    79.246288    52.975483
# 7    2004-08-30    53.810830    11.609764    82.059259    53.810830
# 8    2004-08-31    54.089279     9.541363    79.162541    54.089279
# 9    2004-09-01    54.367728    12.529342    78.654797    54.367728
# 10   2004-09-02    54.646177    10.955881    80.426975    54.646177
# 11   2004-09-03    54.924626    11.882817    80.258220    54.924626
# 12   2004-09-07    56.038422    14.772153    82.971654    56.038422
# 13   2004-09-08    56.316871    14.633448    80.492134    56.316871
# 14   2004-09-09    56.595320    15.274713    83.090700    56.595320
# 15   2004-09-10    56.873768    16.242390    85.894480    56.873768
# 16   2004-09-13    57.709115    18.977773    86.174330    57.709115
# 17   2004-09-14    57.987564    16.820890    86.440141    57.987564
# 18   2004-09-15    58.266013    19.576320    89.087076    58.266013
# 19   2004-09-16    58.544462    18.601459    89.228955    58.544462
# 20   2004-09-17    58.822911    23.234018    87.702354    58.822911
# 21   2004-09-20    59.658258    23.770370    89.950021    59.658258
# 22   2004-09-21    59.936707    22.427493    91.366227    59.936707
# 23   2004-09-22    60.215156    22.803338    89.123452    60.215156
# 24   2004-09-23    60.493605    27.270947    92.641402    60.493605
# 25   2004-09-24    60.772054    25.056013    93.427512    60.772054
# 26   2004-09-27    61.607401    25.321672    92.694517    61.607401
# ...                          ...          ...
# 3668                         0.0  1140.971787
# 3669                         0.0  1141.162997
# 3670                         0.0  1142.589003
# 3671                         0.0  1144.480459
# 3672                         0.0  1146.011616
# 3673                         0.0  1148.178598
# 3674                         0.0  1150.203571
# 3675                         0.0  1151.918963
# 3676                         0.0  1152.533940
# 3677                         0.0  1154.295103
# 3678                         0.0  1156.422306
# 3679                         0.0  1158.080945
# 3680                         0.0  1160.260489
# 3681                         0.0  1162.178843
# 3682                         0.0  1163.666713
# 3683                         0.0  1163.934163
# 3684                         0.0  1165.231323
# 3685                         0.0  1166.784162
# 3686                         0.0  1167.766658
# 3687                         0.0  1169.179158
# 3688                         0.0  1170.252507
# 3689                         0.0  1170.832123
# 3690                         0.0  1170.144225
# 3691                         0.0  1170.456180
# 3692                         0.0  1171.011870
# 3693                         0.0  1171.003464
# 3694                         0.0  1171.449346
# 3695                         0.0  1171.597838
# 3696                         0.0  1171.310871
# 3697                         0.0  1169.829843
#
# [3698 rows x 19 columns]

# %%
# Plot 
goog_model.plot(goog_forecast)
plt.title('GOOG Performance\n1-Yr Forecast\nNo Hold Out Data, Default Parameters')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
# Evaluate across range of changepoint sensitivity
changepoints = [0.01, 0.05, 1.0, 10.0]

for cp in changepoints:
    model = Prophet(daily_seasonality=False, changepoint_prior_scale=cp)
    model.fit(goog_prophet)
    future = model.make_future_dataframe(periods=365)
    forecast = model.predict(future)
    goog_prophet[cp] = forecast['yhat']

# Plot results
plt.figure(figsize=(15,8))

# Acual observations
plt.plot(goog_prophet['ds'], goog_prophet['y'], '.', color='black', label='Actual')

# Different changepoints
colors = {0.01: 'g', 0.05: 'b', 1.0: 'r', 10.0: 'orange'}
for cp in changepoints:
    plt.plot(goog_prophet['ds'], goog_prophet[cp], color=colors[cp], label=cp)

plt.title('GOOG Performance - Changepoint Sensitivity')
plt.legend()
plt.show()

# %%
# Refit iwth changepoint value of 0.05
goog_model = Prophet(daily_seasonality=False, changepoint_prior_scale=0.05)
goog_model.fit(goog_prophet[['ds', 'y']])
goog_future = goog_model.make_future_dataframe(periods=365)
goog_forecast = goog_model.predict(goog_future)

# %%
# Get decomposition components
print('GOOGL Decomposition')
goog_model.plot_components(goog_forecast)
plt.show()
# Out:
# GOOGL Decomposition

# %%
# Validaate model predictions by splitting available data into train/test sets
# Take last 30 days as test data
train = df.dropna().reset_index()[:-30]
train = train.rename(columns={'Date': 'ds', 'Open': 'y'})

test = df.dropna().reset_index()[-30:]
test = test.rename(columns={'Date': 'ds', 'Open': 'y'})

train.head()
# Out:
#    index          ds       y   High     Low   Close    Volume  OpenInt
# 0      0  2004-08-19  50.000  52.03  47.980  50.170  44703800        0
# 1      1  2004-08-20  50.505  54.54  50.250  54.155  22857200        0
# 2      2  2004-08-23  55.375  56.74  54.525  54.700  18274400        0
# 3      3  2004-08-24  55.620  55.80  51.785  52.435  15262600        0
# 4      4  2004-08-25  52.480  54.00  51.940  53.000   9197800        0

# %%
train=train[['ds','y']]
test=test[['ds','y']]
test['ds'] =  pd.to_datetime(test['ds'])

# %%
#forecast=forecast.set_index(['ds'])
test.head()
# Out:
#              ds       y
# 3303 2017-10-02  975.65
# 3304 2017-10-03  967.56
# 3305 2017-10-04  971.76
# 3306 2017-10-05  972.79
# 3307 2017-10-06  980.00

# %%
# Fit model with training data, make 30 days of predictions 
train_model = Prophet(daily_seasonality=True, changepoint_prior_scale=0.05)
train_model.fit(train);
future = train_model.make_future_dataframe(periods=365)
forecast = train_model.predict(future)

# %%
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'daily', 'daily_lower', 'daily_upper', 'weekly', 'weekly_lower',
#        'weekly_upper', 'yearly', 'yearly_lower', 'yearly_upper',
#        'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast.tail()
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 3663 2018-09-25  1122.939955  1052.984950  1188.919467  1064.350740
# 3664 2018-09-26  1123.373008  1045.890395  1190.220471  1064.293225
# 3665 2018-09-27  1123.806060  1051.613078  1191.176313  1063.942819
# 3666 2018-09-28  1124.239113  1049.907415  1186.829803  1063.592412
# 3667 2018-09-29  1124.672165  1053.343185  1188.144344  1063.604554
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 3663  1184.169809       -2.590409             -2.590409             -2.590409
# 3664  1185.068655       -2.067622             -2.067622             -2.067622
# 3665  1185.967502       -1.827754             -1.827754             -1.827754
# 3666  1186.742356       -1.970737             -1.970737             -1.970737
# 3667  1187.230896       -2.546528             -2.546528             -2.546528
#
#          daily     ...         weekly  weekly_lower  weekly_upper    yearly  \
# 3663  0.948374     ...      -0.383712     -0.383712     -0.383712 -3.155072
# 3664  0.948374     ...       0.161570      0.161570      0.161570 -3.177566
# 3665  0.948374     ...       0.451830      0.451830      0.451830 -3.227959
# 3666  0.948374     ...       0.378416      0.378416      0.378416 -3.297528
# 3667  0.948374     ...      -0.118547     -0.118547     -0.118547 -3.376356
#
#       yearly_lower  yearly_upper  multiplicative_terms  \
# 3663     -3.155072     -3.155072                   0.0
# 3664     -3.177566     -3.177566                   0.0
# 3665     -3.227959     -3.227959                   0.0
# 3666     -3.297528     -3.297528                   0.0
# 3667     -3.376356     -3.376356                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 3663                         0.0                         0.0  1120.349546
# 3664                         0.0                         0.0  1121.305385
# 3665                         0.0                         0.0  1121.978306
# 3666                         0.0                         0.0  1122.268375
# 3667                         0.0                         0.0  1122.125637
#
# [5 rows x 22 columns]

# %%
# Plot forecasted results based on training data.  Compare to actual.  
from pylab import rcParams
rcParams['figure.figsize'] = 30, 5
train_model.plot(forecast)
plt.plot(test['ds'], test['y'], label='Actual', color='orange')
plt.title('GOOGL Performance\n1-Yr Forecast\nWith Hold Out Data')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
train_model.plot(forecast)
plt.plot(test['ds'], test['y'], label='Actual', color='orange')
plt.title('GOOG Performance\n1-Yr Forecast\nWith Hold Out Data')
plt.xlim([datetime.date(2016,10,2), datetime.date(2018, 6, 1)])
plt.ylim(0, 1500)
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
# Calculate MSE 
from sklearn.metrics import mean_squared_error
results = forecast[['ds', 'yhat']].merge(test, on='ds')
print('MSE:', mean_squared_error(results.y, results.yhat))

# Calculate residuals
results['residual'] = results['y'] - results['yhat']

# Plot results
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.bar(results.ds, results.residual)
plt.title('Residuals')
plt.xticks(rotation=60)

plt.subplot(122)
plt.hist(results.residual, bins=20)
plt.title('Residuals Histogram')

plt.show()
# Out:
# MSE: 874.2511544844543
